# %%
import bs4
import urllib

# %%
url  = "https://manipalglobal.com"
html = urllib.request.urlopen(url)
bs_obj = bs4.BeautifulSoup(html.read(),'lxml')

# %%
bs_obj.html.head.title
# Out:
# <title>Manipal Global Education Services - Google Digital Marketing | Advanced Excel Program | Online Certification Courses</title>

# %%
bs_obj.html.body.img
# Out:
# <img alt="MAGE" class="lazyload" data-src="/content/dam/manipal/mage/images/logos/logo.png" src=""/>

# %%
bs_obj.html.body.a
# Out:
# <a class="first-top-item gnu-logo" href="/mage.html">
# <img alt="MAGE" class="lazyload" data-src="/content/dam/manipal/mage/images/logos/logo.png" src=""/>
# </a>

# %%
imgs = bs_obj.html.find_all('img')
len(imgs)
# Out:
# 12

# %%
imgs[0].get('data-src')
# Out:
# '/content/dam/manipal/mage/images/logos/logo.png'

# %%
for img in imgs:
    print(img.get('data-src'))
# Out:
# /content/dam/manipal/mage/images/logos/logo.png
# None
# None
# /content/dam/manipal/mage/images/logos/l&T.jpg
# /content/dam/manipal/mage/images/logos/del.jpg
# /content/dam/manipal/mage/images/logos/vir.jpg
# /content/dam/manipal/mage/images/logos/viston.jpg
# /content/dam/manipal/mage/images/logos/emc.jpg
# /content/dam/manipal/mage/images/logos/infosys.png
# /content/dam/manipal/mage/images/galleryImage/tma-pi.JPG.transform/140x93/image.jpg
# /content/dam/manipal/mage/images/logos/mono-logo-footer.png.transform/295x78/image.png
# None

# %%
hyper_link=bs_obj.find_all('a')
for hy in hyper_link:
    print(hy.get('href'))
# Out:
# /mage.html
# /mage/news-events/news-room.html
# /mage/careers.html
# /mage/contact-us.html
# /content.html
# /content.html
# /content.html
# #request4info
# /mage/news-events/news-room.html
# /mage/careers.html
# /mage/contact-us.html
# http://www.manipalprolearn.com/programs/big-data-analytics-using-hadoop-blended
# http://www.manipalprolearn.com/programs/cloud-computing-ms-azure-online
# http://www.manipalprolearn.com/programs/android-app-development-0
# http://www.manipalprolearn.com/programs/itil-foundation-online
# http://www.manipalprolearn.com/programs/advanced-ms-excel
# http://www.manipalprolearn.com/programs//?tid=7
# http://www.manipalprolearn.com/programs/cima-advanced-diploma-management-accounting
# http://www.manipalprolearn.com/programs/management-information-systems
# http://www.manipalprolearn.com/programs/management-accounting
# http://www.manipalprolearn.com/programs/financial-accounting
# http://www.manipalprolearn.com/programs?tid=8
# ...

# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Demographics_of_India'
tables =pd.read_html(url)

# %%
tables[0]
# Out:
#                                                     0  \
# 0                               Demographics of India
# 1   Map showing the population density of each dis...
# 2                                          Population
# 3                                             Density
# 4                                         Growth rate
# 5                                          Birth rate
# 6                                          Death rate
# 7                                     Life expectancy
# 8                                              • male
# 9                                            • female
# 10                                     Fertility rate
# 11                              Infant mortality rate
# 12                                      Age structure
# 13                                         0–14 years
# 14                                        15–64 years
# 15                                        65 and over
# ...

# %%
tables[1]
# Out:
#             0                    1                         2   \
# 0         Year  Maddison (2001)[14]  Clark (1967)[15][16][17]
# 1   Population   % growth / century                Population
# 2    10,000 BC                    —                         —
# 3      4000 BC                    —                         —
# 4      2000 BC                    —                         —
# 5       500 BC                    —                         —
# 6       400 BC                    —                         —
# 7       200 BC                    —                         —
# 8         1 AD             75000000                         —
# 9          200             75000000                         0
# 10         400             75000000                         0
# 11         500             75000000                         0
# 12         600             75000000                         0
# 13         700             75000000                         0
# ...

# %%
# !pip install tweepy
import tweepy
# Out:
# ...
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import tweepy

# %%
consumer_key = "TufHzi954jfLE7O8YHtK2iFx9"
consumer_secret = "x5QhSUCQfV4QYQd5UfRyVeP8tJSMknEJs07WdOXhTGGh3KdfXx"
access_token = "887731387322650624-UTsVRJN1tnwHuGD8TcZNnKuo0OAf9jj"
access_token_secret = "YWY6AWChWiz6OUaV6ePDyJKcVna03P1vP2nYVautvfIEZ"
auth =tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

#accesing twitter api
api =tweepy.API(auth,wait_on_rate_limit =True)
api

# %%
kiki_challenge = api.search('#bobbalalokesh')

# %%
kiki_challenge[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x0000022D1E7A9BA8>, _json={'created_at': 'Fri Mar 01 04:36:40 +0000 2019', 'id': 1101340452546985985, 'id_str': '1101340452546985985', 'text': '#bobbalalokesh fdfsfdsfs', 'truncated': False, 'entities': {'hashtags': [{'text': 'bobbalalokesh', 'indices': [0, 14]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 795698154, 'id_str': '795698154', 'name': 'ravindra', 'screen_name': 'ravindrabvr', 'location': '', 'description': 'Indian.I care for our motherland.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 287, 'listed_count': 0, 'created_at': 'Sat Sep 01 09:20:
# ...

# %%
for kiki in kiki_challenge:
    print(kiki.author.name,kiki.author.favourites_count,kiki.text)
    print('---------')
# Out:
# ravindra 73 #bobbalalokesh fdfsfdsfs
# ---------

# %%
# !pip install mechanicalsoup
# Out:
# ...
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import mechanicalsoup
browser = mechanicalsoup.StatefulBrowser()
browser.open('https://goo.gl/forms/UMkVQlBgOIl3IYzG3')
# Out:
# <Response [200]>

# %%
page = browser.get_current_page()
browser.select_form('form')
browser['entry.5670709'] = 'ravindra'
browser.submit_selected()
# Out:
# <Response [200]>

# %%
page = browser.get_current_page()
browser.select_form('form')
browser['entry.846808492'] = 'yes'
browser.submit_selected()
# Out:
# <Response [200]>
