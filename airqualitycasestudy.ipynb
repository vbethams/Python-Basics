# %%
import numpy as np
import pandas as pd
air = pd.read_csv("airquality.csv",encoding="latin")
air.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
#get 9th day f june
air[(air['Month']==6)& (air['Day']==9)]
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 39          40   71.0    291.0  13.8    90      6    9

# %%
#get 9 th day of june
air[(air['Month']==6)& (air['Day']==9)]
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 39          40   71.0    291.0  13.8    90      6    9

# %%
air
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# 5             6   28.0      NaN  14.9    66      5    6
# 6             7   23.0    299.0   8.6    65      5    7
# 7             8   19.0     99.0  13.8    59      5    8
# 8             9    8.0     19.0  20.1    61      5    9
# 9            10    NaN    194.0   8.6    69      5   10
# 10           11    7.0      NaN   6.9    74      5   11
# 11           12   16.0    256.0   9.7    69      5   12
# 12           13   11.0    290.0   9.2    66      5   13
# 13           14   14.0    274.0  10.9    68      5   14
# 14           15   18.0     65.0  13.2    58      5   15
# 15           16   14.0    334.0  11.5    64      5   16
# ...

# %%
air[air['Month']==6]['Temp'].mean(axis=0)
# Out:
# 79.1

# %%
#find the average of temperature for june
air[air['Month']==6].agg({'Temp':'mean'})
# Out:
# Temp    79.1
# dtype: float64

# %%
air[air['Month']==6]['Temp'].min()
# Out:
# 65

# %%
#to which day of june has least temperature
jun=air[air['Month']==6]
jun.sort_values('Temp').head(1)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 48          49   20.0     37.0   9.2    65      6   18

# %%
#find the maximum ozone value for the month of may
maxi=air[air['Month']==5]
maxi.sort_values('Ozone',ascending=[False]).head(1)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 29          30  115.0    223.0   5.7    79      5   30

# %%
#count of missing values
air['Ozone'].isna().sum(axis=0)
# Out:
# 37

# %%
#find the count of missing values in ozone
air['Ozone'].isna().sum()
# Out:
# 37

# %%
air['Ozone'].mean(axis=0)
# Out:
# 42.12931034482759

# %%
#find out what is mean of ozone
air['Ozone'].agg(['mean'])
# Out:
# mean    42.12931
# Name: Ozone, dtype: float64

# %%
#find out which month has high temperature
te=air.sort_values('Temp',ascending=[False]).head(1)
te['Month']
# Out:
# 119    8
# Name: Month, dtype: int64

# %%
te['Ozone']
# Out:
# 119    76.0
# Name: Ozone, dtype: float64

# %%
#find out the months for which observations carried out
air['Month'].unique()
# Out:
# array([5, 6, 7, 8, 9], dtype=int64)

# %%
#find the ozone and temp for the 1st observation of evry month
air[['Temp','Ozone','Month']].groupby('Month').head(1)
# Out:
#      Temp  Ozone  Month
# 0      67   41.0      5
# 31     78    NaN      6
# 61     84  135.0      7
# 92     81   39.0      8
# 123    91   96.0      9

# %%
#find the highest for every month for ozone
air.groupby('Month')['Ozone'].max()
#air[['Ozone','Month']].sort_values('Ozone',ascending=False)
# Out:
# Month
# 5    115.0
# 6     71.0
# 7    135.0
# 8    168.0
# 9     96.0
# Name: Ozone, dtype: float64

# %%
#find the ozone and temp for the 1st observation of evry month
te=air.groupby('Month').nth(1)
te[['Ozone','Temp']]
#find the highest for every month for ozone
air.groupby('Month').max()['Ozone']
# Out:
#        Ozone  Temp
# Month
# 5       36.0    72
# 6        NaN    74
# 7       49.0    85
# 8        9.0    81
# 9       78.0    92

# %%
#which day of which month correspond to least ozone value
mon=air.sort_values('Ozone').head(1)
mon[['Month','Day']]
# Out:
#     Month  Day
# 20      5   21

# %%
#convert the temperature to centigrade
air['cent']=air.Temp-32 * (5/9)

# %%
import numpy as np
l1=[1,2,4,5,6,45,6,7]
np.sort(l1)
# Out:
# array([ 1,  2,  4,  5,  6,  6,  7, 45])
