# %%
import numpy as np
import pandas as pd
oj = pd.read_csv("oj.csv",encoding="latin")
print(oj)
# Out:
#        store      brand  week    logmove  feat  price     AGE60      EDUC  \
# 0          2  tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2  tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2  tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2  tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2  tropicana    50   9.093357     0   3.87  0.232865  0.248935
# 5          2  tropicana    51   8.877382     0   3.87  0.232865  0.248935
# 6          2  tropicana    52   9.294682     0   3.29  0.232865  0.248935
# 7          2  tropicana    53   8.954674     0   3.29  0.232865  0.248935
# 8          2  tropicana    54   9.049232     0   3.29  0.232865  0.248935
# 9          2  tropicana    57   8.613230     0   3.29  0.232865  0.248935
# 10         2  tropicana    58   8.680672     0   3.56  0.232865  0.248935
# 11         2  tropicana    59   9.034080     0   3.56  0.232865  0.248935
# ...

# %%
#dimesnison
oj.shape
# Out:
# (28947, 17)

# %%
#structure
oj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28947 entries, 0 to 28946
# Data columns (total 17 columns):
# store       28947 non-null int64
# brand       28947 non-null object
# week        28947 non-null int64
# logmove     28947 non-null float64
# feat        28947 non-null int64
# price       28947 non-null float64
# AGE60       28947 non-null float64
# EDUC        28947 non-null float64
# ETHNIC      28947 non-null float64
# INCOME      28947 non-null float64
# HHLARGE     28947 non-null float64
# WORKWOM     28947 non-null float64
# HVAL150     28947 non-null float64
# SSTRDIST    28947 non-null float64
# SSTRVOL     28947 non-null float64
# CPDIST5     28947 non-null float64
# CPWVOL5     28947 non-null float64
# dtypes: float64(13), int64(3), object(1)
# memory usage: 3.8+ MB

# %%
#columns
oj.columns
# Out:
# Index(['store', 'brand', 'week', 'logmove', 'feat', 'price', 'AGE60', 'EDUC',
#        'ETHNIC', 'INCOME', 'HHLARGE', 'WORKWOM', 'HVAL150', 'SSTRDIST',
#        'SSTRVOL', 'CPDIST5', 'CPWVOL5'],
#       dtype='object')

# %%
#describe
oj.describe()
# Out:
#               store          week       logmove          feat         price  \
# count  28947.000000  28947.000000  28947.000000  28947.000000  28947.000000
# mean      80.883511    100.459944      9.167864      0.237261      2.282488
# std       35.576511     34.692314      1.019378      0.425411      0.648001
# min        2.000000     40.000000      4.158883      0.000000      0.520000
# 25%       53.000000     70.000000      8.489616      0.000000      1.790000
# 50%       86.000000    101.000000      9.034080      0.000000      2.170000
# 75%      111.000000    130.000000      9.764685      0.000000      2.730000
# max      137.000000    160.000000     13.482016      1.000000      3.870000
#
#               AGE60          EDUC        ETHNIC        INCOME       HHLARGE  \
# count  28947.000000  28947.000000  28947.000000  28947.000000  28947.000000
# mean       0.173130      0.225220      0.155557     10.616735      0.115602
# ...

# %%
#column in lower 
oj.columns = [x.lower() for x in oj.columns]
print(oj.columns)
# Out:
# Index(['store', 'brand', 'week', 'logmove', 'feat', 'price', 'age60', 'educ',
#        'ethnic', 'income', 'hhlarge', 'workwom', 'hval150', 'sstrdist',
#        'sstrvol', 'cpdist5', 'cpwvol5'],
#       dtype='object')

# %%
#fetch the  first row third column
oj.iloc[0,[2]]
# Out:
# week    40
# Name: 0, dtype: object

# %%
oj.iloc[[0,1,2],[0,1,2]]
# Out:
#    store      brand  week
# 0      2  tropicana    40
# 1      2  tropicana    46
# 2      2  tropicana    47

# %%
#fetch the  first row third column
oj.iloc[0,[2]]
# Out:
# week    40
# Name: 0, dtype: object

# %%
oj.iloc[0:,[0,1,2]]
# Out:
#        store      brand  week
# 0          2  tropicana    40
# 1          2  tropicana    46
# 2          2  tropicana    47
# 3          2  tropicana    48
# 4          2  tropicana    50
# 5          2  tropicana    51
# 6          2  tropicana    52
# 7          2  tropicana    53
# 8          2  tropicana    54
# 9          2  tropicana    57
# 10         2  tropicana    58
# 11         2  tropicana    59
# 12         2  tropicana    60
# 13         2  tropicana    61
# 14         2  tropicana    62
# 15         2  tropicana    63
# 16         2  tropicana    64
# 17         2  tropicana    65
# 18         2  tropicana    66
# 19         2  tropicana    67
# 20         2  tropicana    68
# 21         2  tropicana    69
# 22         2  tropicana    70
# 23         2  tropicana    71
# 24         2  tropicana    72
# 25         2  tropicana    73
# 26         2  tropicana    74
# 27         2  tropicana    75
# 28         2  tropicana    76
# 29         2  tropicana    77
# ...

# %%
#fetch the first second and third columns
oj.iloc[0:,[0,1,2]]
# Out:
#        store      brand  week
# 0          2  tropicana    40
# 1          2  tropicana    46
# 2          2  tropicana    47
# 3          2  tropicana    48
# 4          2  tropicana    50
# 5          2  tropicana    51
# 6          2  tropicana    52
# 7          2  tropicana    53
# 8          2  tropicana    54
# 9          2  tropicana    57
# 10         2  tropicana    58
# 11         2  tropicana    59
# 12         2  tropicana    60
# 13         2  tropicana    61
# 14         2  tropicana    62
# 15         2  tropicana    63
# 16         2  tropicana    64
# 17         2  tropicana    65
# 18         2  tropicana    66
# 19         2  tropicana    67
# 20         2  tropicana    68
# 21         2  tropicana    69
# 22         2  tropicana    70
# 23         2  tropicana    71
# 24         2  tropicana    72
# 25         2  tropicana    73
# 26         2  tropicana    74
# 27         2  tropicana    75
# 28         2  tropicana    76
# 29         2  tropicana    77
# ...

# %%
#fetch the first second eighth and 456 rows of 1,3,6
oj.iloc[[0,1,7,455],[0,2,5]]
# Out:
#      store  week  price
# 0        2    40   3.87
# 1        2    46   3.87
# 7        2    53   3.29
# 455      5    51   2.99

# %%
#fteh the top 5 rows
oj['brand'].head()
# Out:
# 0    tropicana
# 1    tropicana
# 2    tropicana
# 3    tropicana
# 4    tropicana
# Name: brand, dtype: object

# %%
#fetch the top 5 rows of brand ,week feat
oj[['brand','week','feat']].head()
# Out:
#        brand  week  feat
# 0  tropicana    40     0
# 1  tropicana    46     0
# 2  tropicana    47     0
# 3  tropicana    48     0
# 4  tropicana    50     0

# %%
#details of distinct store
oj['store'].unique()
# Out:
# array([  2,   5,   8,   9,  12,  14,  18,  21,  28,  32,  33,  40,  44,
#         45,  47,  48,  49,  50,  51,  52,  53,  54,  56,  59,  62,  64,
#         67,  68,  70,  71,  72,  73,  74,  75,  76,  77,  78,  80,  81,
#         83,  84,  86,  88,  89,  90,  91,  92,  93,  94,  95,  97,  98,
#        100, 101, 102, 103, 104, 105, 106, 107, 109, 110, 111, 112, 113,
#        114, 115, 116, 117, 118, 119, 121, 122, 123, 124, 126, 128, 129,
#        130, 131, 132, 134, 137], dtype=int64)

# %%
#observations for tropicana bramd
oj[oj['brand']=='tropicana']
# Out:
#        store      brand  week    logmove  feat  price     age60      educ  \
# 0          2  tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2  tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2  tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2  tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2  tropicana    50   9.093357     0   3.87  0.232865  0.248935
# 5          2  tropicana    51   8.877382     0   3.87  0.232865  0.248935
# 6          2  tropicana    52   9.294682     0   3.29  0.232865  0.248935
# 7          2  tropicana    53   8.954674     0   3.29  0.232865  0.248935
# 8          2  tropicana    54   9.049232     0   3.29  0.232865  0.248935
# 9          2  tropicana    57   8.613230     0   3.29  0.232865  0.248935
# 10         2  tropicana    58   8.680672     0   3.56  0.232865  0.248935
# 11         2  tropicana    59   9.034080     0   3.56  0.232865  0.248935
# ...

# %%
#fetch all observations of tropicana using query function
tropicana='tropicana'
oj.query("brand=='tropicana'")
# Out:
#        store      brand  week    logmove  feat  price     AGE60      EDUC  \
# 0          2  tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2  tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2  tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2  tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2  tropicana    50   9.093357     0   3.87  0.232865  0.248935
# 5          2  tropicana    51   8.877382     0   3.87  0.232865  0.248935
# 6          2  tropicana    52   9.294682     0   3.29  0.232865  0.248935
# 7          2  tropicana    53   8.954674     0   3.29  0.232865  0.248935
# 8          2  tropicana    54   9.049232     0   3.29  0.232865  0.248935
# 9          2  tropicana    57   8.613230     0   3.29  0.232865  0.248935
# 10         2  tropicana    58   8.680672     0   3.56  0.232865  0.248935
# 11         2  tropicana    59   9.034080     0   3.56  0.232865  0.248935
# ...

# %%
#fetch store brand price for brand tropicana
oj[oj['brand']=='tropicana'][['store','brand','price']]
# Out:
#        store      brand  price
# 0          2  tropicana   3.87
# 1          2  tropicana   3.87
# 2          2  tropicana   3.87
# 3          2  tropicana   3.87
# 4          2  tropicana   3.87
# 5          2  tropicana   3.87
# 6          2  tropicana   3.29
# 7          2  tropicana   3.29
# 8          2  tropicana   3.29
# 9          2  tropicana   3.29
# 10         2  tropicana   3.56
# 11         2  tropicana   3.56
# 12         2  tropicana   3.56
# 13         2  tropicana   3.56
# 14         2  tropicana   3.87
# 15         2  tropicana   2.99
# 16         2  tropicana   2.99
# 17         2  tropicana   3.59
# 18         2  tropicana   3.59
# 19         2  tropicana   2.39
# 20         2  tropicana   2.39
# 21         2  tropicana   3.59
# 22         2  tropicana   2.59
# 23         2  tropicana   2.59
# 24         2  tropicana   3.59
# 25         2  tropicana   3.59
# 26         2  tropicana   2.49
# 27         2  tropicana   3.59
# 28         2  tropicana   3.59
# ...

# %%
#fetch bottom 5
oj.tail()
# Out:
#        store      brand  week    logmove  feat  price     age60      educ  \
# 28942    137  dominicks   156   7.987524     0   2.00  0.209602  0.528362
# 28943    137  dominicks   157   8.502689     0   1.94  0.209602  0.528362
# 28944    137  dominicks   158   9.505991     0   1.59  0.209602  0.528362
# 28945    137  dominicks   159  10.927376     0   1.49  0.209602  0.528362
# 28946    137  dominicks   160   8.859363     0   1.75  0.209602  0.528362
#
#         ethnic    income   hhlarge   workwom   hval150  sstrdist   sstrvol  \
# 28942  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28943  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28944  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28945  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28946  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
#
#        cpdist5   cpwvol5
# 28942  0.77253  0.333761
# ...

# %%
#feth the income,brand,price without the feat
oj[(oj['brand']=='tropicana')&(oj['feat']==0)][['price','INCOME','brand']]
# Out:
#        price     INCOME      brand
# 0       3.87  10.553205  tropicana
# 1       3.87  10.553205  tropicana
# 2       3.87  10.553205  tropicana
# 3       3.87  10.553205  tropicana
# 4       3.87  10.553205  tropicana
# 5       3.87  10.553205  tropicana
# 6       3.29  10.553205  tropicana
# 7       3.29  10.553205  tropicana
# 8       3.29  10.553205  tropicana
# 9       3.29  10.553205  tropicana
# 10      3.56  10.553205  tropicana
# 11      3.56  10.553205  tropicana
# 12      3.56  10.553205  tropicana
# 13      3.56  10.553205  tropicana
# 14      3.87  10.553205  tropicana
# 15      2.99  10.553205  tropicana
# 16      2.99  10.553205  tropicana
# 17      3.59  10.553205  tropicana
# 18      3.59  10.553205  tropicana
# 19      2.39  10.553205  tropicana
# 20      2.39  10.553205  tropicana
# 21      3.59  10.553205  tropicana
# 22      2.59  10.553205  tropicana
# 23      2.59  10.553205  tropicana
# 24      3.59  10.553205  tropicana
# 25      3.59  10.553205  tropicana
# ...

# %%
#add new column 
oj['norminc']=(oj.INCOME - np.mean(oj.INCOME))/np.std(oj.INCOME)
print(oj)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-d3377b12d70e> in <module>()
#       1 #add new column
# ----> 2 oj['norminc']=(oj.INCOME - np.mean(oj.INCOME))/np.std(oj.INCOME)
#       3 print(oj)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'INCOME'

# %%
#remove the column
oj.drop('norminc',axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-07d9570179de> in <module>()
#       1 #remove the column
# ----> 2 oj.drop('norminc',axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
# ...

# %%
#fetch for tropicana excluding store,price,income
cols = [col for col in oj.columns if col not in ['store', 'INCOME','price']]
oj[oj['brand']=='tropicana'][cols]
# Out:
#            brand  week    logmove  feat     AGE60      EDUC   ETHNIC  \
# 0      tropicana    40   9.018695     0  0.232865  0.248935  0.11428
# 1      tropicana    46   8.723231     0  0.232865  0.248935  0.11428
# 2      tropicana    47   8.253228     0  0.232865  0.248935  0.11428
# 3      tropicana    48   8.987197     0  0.232865  0.248935  0.11428
# 4      tropicana    50   9.093357     0  0.232865  0.248935  0.11428
# 5      tropicana    51   8.877382     0  0.232865  0.248935  0.11428
# 6      tropicana    52   9.294682     0  0.232865  0.248935  0.11428
# 7      tropicana    53   8.954674     0  0.232865  0.248935  0.11428
# 8      tropicana    54   9.049232     0  0.232865  0.248935  0.11428
# 9      tropicana    57   8.613230     0  0.232865  0.248935  0.11428
# 10     tropicana    58   8.680672     0  0.232865  0.248935  0.11428
# 11     tropicana    59   9.034080     0  0.232865  0.248935  0.11428
# 12     tropicana    60   8.691483     0  0.232865  0.248935  0.11428
# ...

# %%
#sort the data in increasing order of week
oj.sort_values('week')
# Out:
#        store        brand  week    logmove  feat  price     AGE60      EDUC  \
# 0          2    tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 8141      59  minute.maid    40   7.655391     0   2.62  0.110819  0.233036
# 8025      59    tropicana    40   8.489616     0   3.19  0.110819  0.233036
# 26035    124  minute.maid    40   8.269757     0   3.17  0.119626  0.261876
# 7907      56    dominicks    40   8.565602     1   1.59  0.192889  0.237551
# 7789      56  minute.maid    40   7.560080     0   2.99  0.192889  0.237551
# 7671      56    tropicana    40   8.723231     0   3.66  0.192889  0.237551
# 26156    124    dominicks    40   7.624619     1   1.59  0.119626  0.261876
# 7550      54    dominicks    40   7.592870     1   1.59  0.090222  0.421126
# 7429      54  minute.maid    40   8.302018     0   2.99  0.090222  0.421126
# 7308      54    tropicana    40   8.929568     0   3.66  0.090222  0.421126
# ...

# %%
#sort the dqtq decresing income incresing week
oj.sort_values(['INCOME','week'],ascending=[False,True])
# Out:
#        store        brand  week    logmove  feat  price     AGE60      EDUC  \
# 8373      62    tropicana    40   9.373819     0   3.87  0.222534  0.517760
# 8490      62  minute.maid    40   8.449343     0   3.17  0.222534  0.517760
# 8607      62    dominicks    40   8.050703     1   1.59  0.222534  0.517760
# 8374      62    tropicana    41   9.368369     0   3.87  0.222534  0.517760
# 8491      62  minute.maid    41  10.667652     1   1.99  0.222534  0.517760
# 8608      62    dominicks    41   6.104793     0   2.69  0.222534  0.517760
# 8375      62    tropicana    42   9.570529     0   3.87  0.222534  0.517760
# 8492      62  minute.maid    42   8.754003     0   3.17  0.222534  0.517760
# 8609      62    dominicks    42   6.461468     0   2.69  0.222534  0.517760
# 8376      62    tropicana    43   9.400630     0   3.87  0.222534  0.517760
# 8493      62  minute.maid    43   8.489616     0   3.17  0.222534  0.517760
# ...

# %%
#find the mean of juice price each brand
oj.groupby('brand').agg({'price':'mean'})
# Out:
#                 price
# brand
# dominicks    1.735809
# minute.maid  2.241162
# tropicana    2.870493

# %%
te =oj.groupby('brand')['price'].mean()
type(te)
# Out:
# pandas.core.series.Series

# %%
#find the mean sum std of price each brand
oj[['price','brand']].groupby('brand').agg(['mean','sum','std'])
# Out:
#                 price
#                  mean       sum       std
# brand
# dominicks    1.735809  16748.82  0.385838
# minute.maid  2.241162  21624.97  0.404515
# tropicana    2.870493  27697.39  0.548558

# %%
oj.groupby('brand').agg({'price':['mean','sum','std']})
# Out:
#                 price
#                  mean       sum       std
# brand
# dominicks    1.735809  16748.82  0.385838
# minute.maid  2.241162  21624.97  0.404515
# tropicana    2.870493  27697.39  0.548558

# %%
#for every brand find the mean price and sum of income
oj.groupby('brand').agg({'price':'mean','INCOME':'sum'})
# Out:
#                 price         INCOME
# brand
# dominicks    1.735809  102440.872522
# minute.maid  2.241162  102440.872522
# tropicana    2.870493  102440.872522

# %%
#find the average income for each brand and each store
oj[['INCOME','brand','store']].groupby(['brand','store']).agg(['mean'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-908206b98953> in <module>()
#       1 #find the average income for each brand and each store
# ----> 2 oj[['INCOME','brand','store']].groupby(['brand','store']).agg(['mean'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
#find mean and std of income
oj['INCOME'].agg(['mean','std'])
# Out:
# mean    10.616735
# std      0.282314
# Name: INCOME, dtype: float64

# %%
#mean of income graeter than or equal to 10.5
oj[oj['INCOME']>=10.5].agg(['mean'])
# Out:
#           store        week   logmove      feat     price     AGE60      EDUC  \
# mean  78.439509  100.578171  9.112568  0.236898  2.270229  0.167909  0.253437
#
#         ETHNIC     INCOME  HHLARGE  WORKWOM   HVAL150  SSTRDIST   SSTRVOL  \
# mean  0.079455  10.759452  0.11639   0.3701  0.406293  4.176384  1.181963
#
#        CPDIST5   CPWVOL5
# mean  2.198674  0.497842

# %%
oj[oj['INCOME']>=10.5].mean()
# Out:
# store        78.439509
# week        100.578171
# logmove       9.112568
# feat          0.236898
# price         2.270229
# AGE60         0.167909
# EDUC          0.253437
# ETHNIC        0.079455
# INCOME       10.759452
# HHLARGE       0.116390
# WORKWOM       0.370100
# HVAL150       0.406293
# SSTRDIST      4.176384
# SSTRVOL       1.181963
# CPDIST5       2.198674
# CPWVOL5       0.497842
# dtype: float64

# %%
#for each brand having price >=2.5 find mean median sd of log of income
oj['incom']=np.log(oj['INCOME'])
oj[oj['price']>=2.5].groupby('brand').agg({'incom':['mean','std','median']})
# Out:
#                 incom
#                  mean       std    median
# brand
# dominicks    2.348104  0.038822  2.338646
# minute.maid  2.360556  0.028522  2.363903
# tropicana    2.361968  0.026782  2.364181

# %%
#cross tabulation of brands and feature adverisement
pd.crosstab(oj.brand,oj.feat)
# Out:
# feat            0     1
# brand
# dominicks    7169  2480
# minute.maid  6865  2784
# tropicana    8045  1604

# %%
oj[(oj['INCOME']>2)&(oj['price']>2)]
# Out:
#        store        brand  week    logmove  feat  price     AGE60      EDUC  \
# 0          2    tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2    tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2    tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2    tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2    tropicana    50   9.093357     0   3.87  0.232865  0.248935
# 5          2    tropicana    51   8.877382     0   3.87  0.232865  0.248935
# 6          2    tropicana    52   9.294682     0   3.29  0.232865  0.248935
# 7          2    tropicana    53   8.954674     0   3.29  0.232865  0.248935
# 8          2    tropicana    54   9.049232     0   3.29  0.232865  0.248935
# 9          2    tropicana    57   8.613230     0   3.29  0.232865  0.248935
# 10         2    tropicana    58   8.680672     0   3.56  0.232865  0.248935
# ...

# %%
#how to find the columns from 4 to 19 and rows 4 to 10 using iloc
oj.iloc[3:11,3:19]
# Out:
#      logmove  feat  price     AGE60      EDUC   ETHNIC     INCOME   HHLARGE  \
# 3   8.987197     0   3.87  0.232865  0.248935  0.11428  10.553205  0.103953
# 4   9.093357     0   3.87  0.232865  0.248935  0.11428  10.553205  0.103953
# 5   8.877382     0   3.87  0.232865  0.248935  0.11428  10.553205  0.103953
# 6   9.294682     0   3.29  0.232865  0.248935  0.11428  10.553205  0.103953
# 7   8.954674     0   3.29  0.232865  0.248935  0.11428  10.553205  0.103953
# 8   9.049232     0   3.29  0.232865  0.248935  0.11428  10.553205  0.103953
# 9   8.613230     0   3.29  0.232865  0.248935  0.11428  10.553205  0.103953
# 10  8.680672     0   3.56  0.232865  0.248935  0.11428  10.553205  0.103953
#
#      WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5   CPWVOL5    incom
# 3   0.303585  0.463887  2.110122  1.142857  1.92728  0.376927  2.35643
# 4   0.303585  0.463887  2.110122  1.142857  1.92728  0.376927  2.35643
# 5   0.303585  0.463887  2.110122  1.142857  1.92728  0.376927  2.35643
# ...

# %%
oj[(oj['brand']=='tropicana')&(oj['week']>40) &(oj['week']<50)]['inc'].agg(['mean','std'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'inc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-883c7d820564> in <module>()
# ...

# %%
import re
list1=[]
list2=[]
list3=[]
list4=[]
str1 = "Email_Address,Nickname,Group_Status,Join_Yearaa@aaa.com,aa,Owner,2014bb@bbb.com,bb,Member,2015cc@ccc.com,cc,Member,2017dd@ddd.com,dd,Member,2016e@eee.com,ee,Member,2020"
y=re.findall('@.+',str1)
for i in y:
    list1=i.split(',')
for i in list1:
    if '@' in i:
        list2.append(i)
for i in list2:
    y= i.split('@')
    list3.append(y[1])
for i in list3:
    y=i.split('.')
    list4.append(y[0])
print(list4)
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
